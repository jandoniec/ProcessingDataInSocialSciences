# %% [markdown]
# <a href="https://colab.research.google.com/github/jandoniec/ProcessingDataInSocialSciences/blob/main/Computer_usage_in_company.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 20. Authors
#
# 1. Jan Paluch 226092
# 2. Jan Doniec 226504
# 3. Wladyslaw Pniewski 226667

# %% [markdown]
# # 21. Operating system
#
# An operating system (OS) is a type of system software that manages computer hardware and software resources and provides common services for computer programs. The operating system acts as an intermediary between users and the computer hardware.
#
# The main functions of an operating system include managing the computer’s memory, processes, and all of its software and hardware. It allows users to interact with the computer without needing to know how to speak the computer’s language. The OS handles input from the keyboard, mouse, and other devices and sends output to the display screen or printers.
#
# **Main goals of the operating system:**
# - Efficient management of hardware and software resources
# - Providing a user-friendly interface for interaction
# - Enabling multitasking and process management

# %% [markdown]
# # 22. Types of operating systems
#
# **Windows** is a series of operating systems developed by Microsoft. It is known for its graphical user interface (GUI), which allows users to easily navigate and control their computer. Windows is widely used in personal computers, laptops, and servers, and is valued for its compatibility with a wide range of hardware and software applications.
#
# ![Windows Logo](https://upload.wikimedia.org/wikipedia/commons/thumb/0/0a/Unofficial_Windows_logo_variant_-_2002%E2%80%932012_%28Multicolored%29.svg/1161px-Unofficial_Windows_logo_variant_-_2002%E2%80%932012_%28Multicolored%29.svg.png)
# [Read more about Windows on Wikipedia](https://en.wikipedia.org/wiki/Microsoft_Windows)
#
# ---
#
# **Linux** is an open-source operating system based on Unix. It is popular for its stability, security, and flexibility. Linux is commonly used in servers, supercomputers, and increasingly on desktop computers by tech-savvy users. Various distributions (distros) like Ubuntu, Fedora, and Debian cater to different needs and preferences.
#
# ![Linux Logo](https://upload.wikimedia.org/wikipedia/commons/thumb/3/35/Tux.svg/1200px-Tux.svg.png)
# [Read more about Linux on Wikipedia](https://en.wikipedia.org/wiki/Linux)
#
# ---
#
# **iOS** is a mobile operating system created and developed by Apple Inc. It is the system behind devices like the iPhone and iPad. iOS is known for its smooth performance, tight security, and seamless integration with Apple's ecosystem. It provides a user-friendly interface and a vast selection of apps via the App Store.
#
# ![iOS Logo](https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/IOS_logo.svg/2048px-IOS_logo.svg.png)
# [Read more about iOS on Wikipedia](https://en.wikipedia.org/wiki/IOS)

# %% [markdown]
# # 23. Advantages and disadvantages of operating systems
#
# | Operating System | Advantages | Disadvantages |
# |------------------|-------------|---------------|
# | **Windows** | - Wide hardware and software compatibility<br>- User-friendly interface | - Vulnerable to viruses and malware<br>- Paid license cost |
# | **Linux** | - Free and open-source<br>- High security and stability | - Steeper learning curve for beginners<br>- Limited support for some proprietary software |
# | **macOS** | - Seamless integration with Apple devices<br>- Strong security and stability | - Expensive hardware requirements<br>- Less flexibility for hardware customization |

# %% [markdown]
# # 24.Use of operating systems in the company

# %% [markdown]
# #### a. Create an alphabetical list of company departments containing an alphabetical list of employees employed in those departments

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
employees = pd.read_csv("employees.csv", sep=";")
employees.sort_values(by=["department", "name"])
# Out:
#     id                name              department  computer
# 10  11     BUNNING, Gretal           Cybersecurity         1
# 0    1         PISCO, Barb           Cybersecurity         4
# 14  15     SANFORD, Stavro           Cybersecurity        15
# 3    4    CUTFORD, Adolpho  Data Science Analytics         8
# 8    9   FUSEDALE, Laureen  Data Science Analytics         5
# 4    5      PHEAT, Gwyneth  Data Science Analytics        12
# 11  12      BENION, Farrel                  DevOps         9
# 2    3  SOBIESKI, Elisabet                  DevOps         7
# 6    7       HALLARD, Mela         Human Resources         2
# 1    2      ANKER, Phillip    Software Development         6
# 5    6        BAUGHEN, Ari    Software Development        13
# 7    8  COTTEREL, Rodrique    Software Development         3
# 13  14       OLLIN, Walden    Software Development        14
# 9   10    PACKWOOD, Stinky    Software Development        10
# ...

# %% [markdown]
# #### b. Calculate and present an alphabetical list of the company's departments along with the number of people employed in those departments

# %%
employees[["department"]].groupby(["department"])["department"].count()
# Out:
# department
# Cybersecurity             3
# Data Science Analytics    3
# DevOps                    2
# Human Resources           1
# Software Development      6
# Name: department, dtype: int64

# %% [markdown]
# #### c. Calculate and present the number of employees who use each of the operating systems, in alphabetical order

# %%
computers=pd.read_csv("computers.csv", sep=";")
systems=pd.read_csv("systems.csv", sep=";")

# %% [markdown]
# #### d. Create a graph with the results of the calculations from the previous task

# %% [markdown]
# ##### e. Calculate and present an alphabetical list of company departments including an alphabetical list of operating systems and the number of employees who use them

# %% [markdown]
# ##### f. Create a chart with the results of the calculations from the previous task

# %% [markdown]
# # 25. File system

# %% [markdown]
# #### a. Describe in at least two paragraphs what a file system is

# %% [markdown]
# In computing, a file system or filesystem (often abbreviated to FS or fs) governs file organization and access. A local file system is a capability of an operating system that services the applications running on the same computer. A distributed file system is a protocol that provides file access between networked computers.
#
# A file system provides a data storage service that allows applications to share mass storage. Without a file system, applications could access the storage in incompatible ways that lead to resource contention, data corruption and data loss.

# %% [markdown]
# #### b. List the main goals of the file system in bullet points

# %% [markdown]
# ## Main goals of a file system:
#
# - Defining file names
# - Storing files on a storage device
# - Retrieving files from a storage device

# %% [markdown]
# #### c. List at least three file systems in bullet points

# %% [markdown]
# ## Types of file systems:
#
# - NTFS
# - exFAT
# - Ext4

# %% [markdown]
# # 26.Use of computers by company employees

# %% [markdown]
# #### a. Create an alphabetical list of computer names and the names of people who use them, sorted alphabetically

# %%
computers.sort_values(by=["computer"])
# Out:
#     id         computer  ram_gb  ssd_gb  system
# 3    4      Asus ProArt       8     256       3
# 4    5      Asus ProArt      32     512       4
# 6    7      Asus ProArt      16     512       3
# 2    3    Dell Inspiron      32    1024       4
# 9   10    Dell Inspiron      32     256       4
# 11  12    Dell Inspiron      16    1024       3
# 1    2  Lenovo ThinkPad      32     128       4
# 5    6  Lenovo ThinkPad      16     256       3
# 7    8  Lenovo ThinkPad       8     256       3
# 12  13  Lenovo ThinkPad      16    1024       3
# 0    1     Mac Book Air      16     512       5
# 10  11     Mac Book Air      16     128       5
# 14  15     Mac Book Air      16     128       5
# 8    9     Mac Book Pro      32     256       5
# 13  14     Mac Book Pro      16    1024       5

# %% [markdown]
# #### b. Calculate and present the names of computers and the number of people who use them

# %%
computer_usage = computers.groupby('computer')['computer'].count().reset_index(name='users')
computer_usage
# Out:
#           computer  users
# 0      Asus ProArt      3
# 1    Dell Inspiron      3
# 2  Lenovo ThinkPad      4
# 3     Mac Book Air      3
# 4     Mac Book Pro      2

# %% [markdown]
# #### c. Calculate and present an alphabetical list of employees along with the total number of files they have (private and shared)

# %% [markdown]
# #### d. Create a chart with the number of files available for each operating system

# %% [markdown]
# #### e. Calculate and present a list of employees along with the total volume of files in megabytes that they have on their computers, sorted by the total volume in descending order
