# %% [markdown]
# # Calculate Body Mass Index (BMI)

# %%
weight = int(input());
height = float(input());
x = weight/float(height*height);
print(x)
if x < 18.5:
    print('Niedowaga')
if x>=18.5 and x<25:
    print("Normalnie")
if x >= 25 and x < 30:
   print('Nadwaga')
if x >= 30:
   print('Otylosc')
