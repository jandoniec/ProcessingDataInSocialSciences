# %% [markdown]
# <a href="https://colab.research.google.com/github/jandoniec/ProcessingDataInSocialSciences/blob/main/EUROPA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Based on the file european-countries.csv, create a DataFrame. Then, do the following tasks:
#
# display currency names alphabetically (only one column)
# display data organised by the population, descending
# display data organised by the region and then by the country
# display data organised by the population density (first, add an extra column)
# display the name of the capital and currency (only two columns), arrange the data by currency and then by the name of the capital city

# %%
import pandas as pd

# %%
europa = pd.read_csv('european-countries.csv')

# %%
europa
# Out:
#                       Name            Region     Capital    Area  Population  \
# 0                  Austria    Central Europe      Vienna   83871     9119533
# 1                  Belarus    Eastern Europe       Minsk  207600     9398867
# 2   Bosnia and Herzegovina  Southeast Europe    Sarajevo   51129     3295931
# 3                 Bulgaria  Southeast Europe       Sofia  110994     6818088
# 4                  Croatia  Southeast Europe      Zagreb   56594     4040905
# 5           Czech Republic    Central Europe      Prague   78866    10706997
# 6                  Estonia   Northern Europe     Tallinn   43515     1329959
# 7                  Hungary    Central Europe    Budapest   93030     9660349
# 8                   Latvia   Northern Europe        Riga   64589     1899500
# 9                Lithuania   Northern Europe     Vilnius   62688     2794290
# 10                 Moldova    Eastern Europe    Chișinău   33843     2597000
# ...

# %%
europa['Currency'].sort_values()
# Out:
# 1             Belarusian ruble (BYN)
# 2     Bosnian convertible mark (BAM)
# 3                Bulgarian lev (BGN)
# 4                Croatian kuna (HRK)
# 5                 Czech koruna (CZK)
# 0                         Euro (EUR)
# 6                         Euro (EUR)
# 8                         Euro (EUR)
# 9                         Euro (EUR)
# 13                        Euro (EUR)
# 14                        Euro (EUR)
# 7             Hungarian forint (HUF)
# 10                Moldovan leu (MDL)
# 11                Polish złoty (PLN)
# 12                Romanian leu (RON)
# 15           Ukrainian hryvnia (UAH)
# Name: Currency, dtype: object

# %%
europa.sort_values('Population', ascending=False)
# Out:
#                       Name            Region     Capital    Area  Population  \
# 15                 Ukraine    Eastern Europe        Kyiv  603550    42990498
# 11                  Poland    Central Europe      Warsaw  312679    38036287
# 12                 Romania  Southeast Europe   Bucharest  238391    19193261
# 5           Czech Republic    Central Europe      Prague   78866    10706997
# 7                  Hungary    Central Europe    Budapest   93030     9660349
# 1                  Belarus    Eastern Europe       Minsk  207600     9398867
# 0                  Austria    Central Europe      Vienna   83871     9119533
# 3                 Bulgaria  Southeast Europe       Sofia  110994     6818088
# 13                Slovakia    Central Europe  Bratislava   49035     5465662
# 4                  Croatia  Southeast Europe      Zagreb   56594     4040905
# 2   Bosnia and Herzegovina  Southeast Europe    Sarajevo   51129     3295931
# ...

# %%
europa.sort_values(['Region', 'Name'])
# Out:
#                       Name            Region     Capital    Area  Population  \
# 0                  Austria    Central Europe      Vienna   83871     9119533
# 5           Czech Republic    Central Europe      Prague   78866    10706997
# 7                  Hungary    Central Europe    Budapest   93030     9660349
# 11                  Poland    Central Europe      Warsaw  312679    38036287
# 13                Slovakia    Central Europe  Bratislava   49035     5465662
# 14                Slovenia    Central Europe   Ljubljana   20273     2100795
# 1                  Belarus    Eastern Europe       Minsk  207600     9398867
# 10                 Moldova    Eastern Europe    Chișinău   33843     2597000
# 15                 Ukraine    Eastern Europe        Kyiv  603550    42990498
# 6                  Estonia   Northern Europe     Tallinn   43515     1329959
# 8                   Latvia   Northern Europe        Riga   64589     1899500
# ...

# %%
europa['Population Density'] = europa['Population'] / europa['Area']
europa.sort_values('Population Density')
# Out:
#                       Name            Region     Capital    Area  Population  \
# 8                   Latvia   Northern Europe        Riga   64589     1899500
# 6                  Estonia   Northern Europe     Tallinn   43515     1329959
# 9                Lithuania   Northern Europe     Vilnius   62688     2794290
# 1                  Belarus    Eastern Europe       Minsk  207600     9398867
# 3                 Bulgaria  Southeast Europe       Sofia  110994     6818088
# 2   Bosnia and Herzegovina  Southeast Europe    Sarajevo   51129     3295931
# 15                 Ukraine    Eastern Europe        Kyiv  603550    42990498
# 4                  Croatia  Southeast Europe      Zagreb   56594     4040905
# 10                 Moldova    Eastern Europe    Chișinău   33843     2597000
# 12                 Romania  Southeast Europe   Bucharest  238391    19193261
# 14                Slovenia    Central Europe   Ljubljana   20273     2100795
# ...

# %%
europa[['Capital', 'Currency']].sort_values(['Currency', 'Capital'])
# Out:
#        Capital                        Currency
# 1        Minsk          Belarusian ruble (BYN)
# 2     Sarajevo  Bosnian convertible mark (BAM)
# 3        Sofia             Bulgarian lev (BGN)
# 4       Zagreb             Croatian kuna (HRK)
# 5       Prague              Czech koruna (CZK)
# 13  Bratislava                      Euro (EUR)
# 14   Ljubljana                      Euro (EUR)
# 8         Riga                      Euro (EUR)
# 6      Tallinn                      Euro (EUR)
# 0       Vienna                      Euro (EUR)
# 9      Vilnius                      Euro (EUR)
# 7     Budapest          Hungarian forint (HUF)
# 10    Chișinău              Moldovan leu (MDL)
# 11      Warsaw              Polish złoty (PLN)
# 12   Bucharest              Romanian leu (RON)
# 15        Kyiv         Ukrainian hryvnia (UAH)
